# %%
#importing the required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#Class 3 material requires the libraries below in addition to the libraries above
import PIL
import requests
import scipy

# %%
np.random.seed(613) #setting the random seed for reproducability
x = np.arange(50) #Generating the x interval scale (from 0 to 49)
y = np.random.randint(0,100,50) #Generating the y interval scale (50 randomly generated integers between 0 and 100)
fig, ax = plt.subplots(figsize = (5,3)) #figsize = (5,3) specifies the width and height of the plot in inches
ax.scatter(x,y) #Making the scatterplot

# %%
#changing the width and height of the scatterplot
fig, ax = plt.subplots(figsize = (9,3)) 
ax.scatter(x,y) #Making the scatterplot

# %%
fig, ax = plt.subplots(figsize = (5,3)) 
ax.bar(x,y) #Making a bar plot
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize = (5,3)) 
ax.plot(x,y) #Making a line plot

# %%
fig, ax = plt.subplots(figsize = (5,3)) 
ax.hist(y) #making a histogram
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig,ax = plt.subplots(figsize = (5,3))
ax.plot(x,y) # Generating a line plot with axis labels

ax.set_title ('Total growth over time')# Adding a title to the plot
ax.set_ylabel('Total Growth')# Labeling the y-axis
ax.set_xlabel('Years since start')# Labeling the x-axis
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# Using custom font styles for the plot
font1 = {'family':'sans-serif','color':'blue','size': 20}
font2 = {'family':'monospace','color':'green','size':14}

fig,ax = plt.subplots(figsize = (5,3))
ax.plot(x,y)# Generating a line plot

ax.set_title('Total growth over time', fontdict = font1)# fontdict=font1 applies the defined font properties to the title
ax.set_ylabel('Total growth', fontdict = font2)# fontdict=font2 applies the defined font properties to the y-axis label
ax.set_xlabel('Years since start', fontdict= font2)# fontdict=font2 applies the defined font properties to the x-axis label
# Out:
# Text(0.5, 0, 'Years since start')

# %%
#Same plot as the one above but with the title left-aligned
#By default the title is center-aligned
# Using custom font styles for the plot
font1 = {'family':'sans-serif','color':'blue','size': 20}
font2 = {'family':'monospace','color':'green','size':14}

fig,ax = plt.subplots(figsize = (5,3))
ax.plot(x,y)# Generating a line plot

ax.set_title('Total growth over time', fontdict = font1, loc = 'left')# fontdict=font1 applies the defined font properties to the title
ax.set_ylabel('Total growth', fontdict = font2)# fontdict=font2 applies the defined font properties to the y-axis label
ax.set_xlabel('Years since start', fontdict= font2)# fontdict=font2 applies the defined font properties to the x-axis label
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y,
           marker = '*', # marker='*': Specifies that the shape of the marker for each data point is a star
           color = 'indigo') # color='indigo': Specifies the color of the markers as indigo

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
           marker = '*', # Marker shape set to a circle ('o')
           color = 'indigo', # Line color set to indigo
           linestyle = '--',  # Line style set to dashed ('--')
           linewidth = 2)  # Line width set to 2

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
           marker = '*', # Marker shape set to a circle ('o')
           color = 'indigo', # Line color set to indigo
           linestyle = '--',  # Line style set to dashed ('--')
           linewidth = 4)  # Line width set to 4

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
           marker = '*', # Marker shape set to a circle ('o')
           color = 'indigo', # Line color set to indigo
           linestyle = '--',  # Line style set to dashed ('--')
           linewidth = 2,  # Line width set to 2,
           markersize = 12,
           markeredgecolor = '#fa9359', # Edge color of the marker set to gold? (hex: #fa9359)
           markerfacecolor = '#000000') # Fill color of the marker set to black (hex: #000000)

# %%
#Same plot as above but with grid lines, both horizontal and vertical

fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
           marker = '*', # Marker shape set to a circle ('o')
           color = 'indigo', # Line color set to indigo
           linestyle = '--',  # Line style set to dashed ('--')
           linewidth = 2,  # Line width set to 2,
           markersize = 12,
           markeredgecolor = '#fa9359', # Edge color of the marker set to gold? (hex: #fa9359)
           markerfacecolor = '#000000') # Fill color of the marker set to black (hex: #000000)
ax.grid()

# %%
#Same plot as above but with only horizontal grid lines

fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
           marker = '*', # Marker shape set to a circle ('o')
           color = 'indigo', # Line color set to indigo
           linestyle = '--',  # Line style set to dashed ('--')
           linewidth = 2,  # Line width set to 2,
           markersize = 12,
           markeredgecolor = '#fa9359', # Edge color of the marker set to gold? (hex: #fa9359)
           markerfacecolor = '#000000') # Fill color of the marker set to black (hex: #000000)
ax.grid(axis = 'y') #can also try axis = 'x' to have only vertical grid lines

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
           marker = '*', # Marker shape set to a circle ('o')
           color = 'indigo', # Line color set to indigo
           linestyle = '--',  # Line style set to dashed ('--')
           linewidth = 2,  # Line width set to 2,
           markersize = 12,
           markeredgecolor = '#fa9359', # Edge color of the marker set to gold? (hex: #fa9359)
           markerfacecolor = '#000000') # Fill color of the marker set to black (hex: #000000)
ax.grid(axis = 'y',
        color = 'blue',
        linewidth = 2,
        linestyle = 'dotted') #represent horizontal grid line with dotted line of blue color and line width 2

# %% [markdown]
# Classes 1 and 2 involved the material covered above (in addition to non-coding material). Class 3 notes begin below.

# %%
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
#Line plots
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1)
ax.plot(x,y2)

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y1,label = "Person 1")
ax.plot(x,y2,label = "Person 2")
ax.legend(loc = "lower right")

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = "lower right",
          frameon = True,
          fontsize = 12,
          ncol = 2,
          shadow = True)

# %%
#Moving the legend outside the plotting area
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = "lower left",
          bbox_to_anchor=(1,1))

# %%
#Moving the legend outside the plotting area
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = "lower left",
          bbox_to_anchor=(1,0.5))

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = "upper right",
          bbox_to_anchor=(-0.1,1))

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")
ax.text(10,95, "This value is important!")
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")
ax.text(10,95, "This value is important!",
        ha = 'center',
        color = 'red',
        size = 20)
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots()
ax.axis([0,10,0,10])

ax.text(1,5,"Data: (1,5)", transform = ax.transData)
ax.text(0.5,0.1,"Axes: (0.5,0.1)", transform = ax.transAxes)
ax.text(0.2,0.2,"Figure: (0.2,0.2)", transform = fig.transFigure)
# Out:
# Text(0.2, 0.2, 'Figure: (0.2,0.2)')

# %%
fig, ax = plt.subplots()
ax.axis([0,10,0,10])

ax.text(1,5,"Data: (1,5)", transform = ax.transData)
ax.text(0.5,0.1,"Axes: (0.5,0.1)", transform = ax.transAxes)
ax.text(0.9,0.9,"Figure: (0.9,0.9)", transform = fig.transFigure)
# Out:
# Text(0.9, 0.9, 'Figure: (0.9,0.9)')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.annotate("This is important!", xy = (10,95), xytext=(20,94),
            arrowprops = dict(facecolor = 'black',
                              shrink = 0.05))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.annotate("This is important!", xy = (10,95), xytext=(20,94),
            arrowprops = dict(arrowstyle = 'wedge'
                               ))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.annotate("This is important!", xy = (10,95), xytext=(20,94),
            arrowprops = dict(arrowstyle = 'wedge', color = 'hotpink'
                               ))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

plt.xticks(rotation = 45,ha = 'right') #ha stands for horizontal alignment. here, ha is right aligned
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
plt.style.use('default')
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)

# %%
font1 = {'family':'serif','color':'indigo'}
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")
ax.legend(loc="lower right")

plt.xlabel("Shiny New X Axis!", fontsize=18,fontdict=font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0,75,50)
x2 = np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y2 = np.array([110,180,240,99,220])

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2,
                               nrows = 1,
                               figsize=(7,3))
ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=1,
                               nrows = 2,
                               figsize=(7,3))
ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2,
                               nrows = 1,
                               figsize=(9,3))
font1 = {'family': 'serif', 'size': 10} #for axis titles
font2 = {'family': 'serif', 'size': 14} #for each plot title
ax1.scatter(x1,y1, marker = 'o', color = 'red')
ax2.bar(x2,y2, color = 'darkgreen')
# Out:
# <BarContainer object of 5 artists>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2,
                               nrows = 1,
                               figsize=(9,3))
font1 = {'family': 'serif', 'size': 10} #for axis titles
font2 = {'family': 'serif', 'size': 14} #for each plot title
ax1.scatter(x1,y1, marker = 'o', color = 'red')
ax2.bar(x2,y2, color = 'darkgreen')

ax1.set_title('Important Scatterplot', fontdict = font2)
ax1.set_ylabel('Measure', fontdict = font1)
ax1.set_xlabel('Time', fontdict = font1)

ax2.set_title('Pirate Strength', fontdict = font2)
ax2.set_ylabel('Strength', fontdict = font1)
ax2.set_xlabel('Pirate Crew Member', fontdict = font1)
# Out:
# Text(0.5, 0, 'Pirate Crew Member')

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                   figsize=(7, 4))

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                   figsize=(7, 4))

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel("A Big Label!",fontsize=18)
someaxes["ax2"].set_xlabel("Another Label",fontsize=18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious",fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                   figsize=(7, 4),
                                   layout = "constrained")

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel("A Big Label!",fontsize=18)
someaxes["ax2"].set_xlabel("Another Label",fontsize=18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious",fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
x = np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y1 = np.array([110,180,240,99,220])
y2 = np.array([170,100,90,120,50])

fig, ax = plt.subplots(figsize=(7,3))

ax.bar(x,y1,
       color='indigo')
ax.plot(x,y2,
        color = 'red')

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')

# %%
#Adding error bars using standard deviation of our data
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')

ax.errorbar(x, #our x values
            y2, #our y values
            yerr = y2_sd,
            fmt = "none")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red', linewidth = 3)

ax.errorbar(x, #our x values
            y2, #our y values
            yerr = y2_sd,
            fmt = "none",
            ecolor = 'indigo',
            elinewidth = 4,
            capsize = 6,
            capthick =4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red', linewidth = 3)

ax.errorbar(x, #our x values
            y2, #our y values
            yerr = y2_sd,
            fmt = "none",
            ecolor = 'indigo',
            elinewidth = 4,
            capsize = 6,
            capthick =4,
            errorevery =2)
# Out:
# <ErrorbarContainer object of 3 artists>
